# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10846
# 1   1027     Ethereum    ETH      ethereum              8492
# 2    825  Tether USDt   USDT        tether             76728
# 3   1839          BNB    BNB           bnb              2081
# 4   5426       Solana    SOL        solana               630
# 5     52          XRP    XRP           xrp              1237
# 6   3408         USDC   USDC      usd-coin             17001
# 7   2010      Cardano    ADA       cardano              1086
# 8     74     Dogecoin   DOGE      dogecoin               901
# 9   5805    Avalanche   AVAX     avalanche               674
# 10  5994    Shiba Inu   SHIB     shiba-inu               749
# 11  6636     Polkadot    DOT  polkadot-new               697
# 12  1958         TRON    TRX          tron               937
# 13  1975    Chainlink   LINK     chainlink              1664
# 14  3890      Polygon  MATIC       polygon              1296
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2020-07-13T00:00:00.000Z
# 10  2020-08-01T00:00:00.000Z
# 11  2020-08-19T00:00:00.000Z
# 12  2017-09-13T00:00:00.000Z
# 13  2017-09-20T00:00:00.000Z
# 14  2019-04-28T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 6   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 7   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
# 10      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 11  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 12  [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 13  [platform, defi, oracles, smart-contracts, sub...  1.000000e+09
# 14  [pos, platform, enterprise-solutions, zero-kno...  1.000000e+10
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.964415e+07  1.964415e+07            False       NaN         1
# 1         1.201331e+08  1.201331e+08             True       NaN         2
# 2         9.951523e+10  1.028001e+11             True       NaN         3
# 3         1.495417e+08  1.495417e+08            False       NaN         4
# 4         4.429432e+08  5.710439e+08             True       NaN         5
# 5         5.466403e+10  9.998785e+10            False       NaN         6
# 6         2.895219e+10  2.895219e+10            False       NaN         7
# 7         3.548478e+10  3.667143e+10            False       NaN         8
# 8         1.433239e+11  1.433239e+11             True       NaN         9
# 9         3.772527e+08  4.359423e+08            False       NaN        10
# 10        5.892894e+14  5.895341e+14            False       NaN        11
# 11        1.285541e+09  1.417802e+09             True       NaN        12
# 12        8.795383e+10  8.795388e+10             True       NaN        13
# 13        5.871000e+08  1.000000e+09            False       NaN        14
# 14        9.899143e+09  1.000000e+10            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                               NaN                       NaN      None
# 11                               NaN                       NaN      None
# 12                      7.165966e+10              1.002298e+10      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-03-04T06:22:00.000Z     63575.995748          3.496961e+10
# 1   2024-03-04T06:22:00.000Z      3469.484806          1.612984e+10
# 2   2024-03-04T06:21:00.000Z         1.000504          8.074829e+10
# 3   2024-03-04T06:21:00.000Z       414.609738          1.891551e+09
# 4   2024-03-04T06:22:00.000Z       129.069012          3.270762e+09
# 5   2024-03-04T06:22:00.000Z         0.624696          2.211938e+09
# 6   2024-03-04T06:22:00.000Z         0.999907          6.841049e+09
# 7   2024-03-04T06:21:00.000Z         0.779533          1.175344e+09
# 8   2024-03-04T06:22:00.000Z         0.162487          4.815500e+09
# 9   2024-03-04T06:21:00.000Z        42.317683          5.816149e+08
# 10  2024-03-04T06:21:00.000Z         0.000025          3.528777e+09
# 11  2024-03-04T06:21:00.000Z         9.814043          7.167697e+08
# 12  2024-03-04T06:21:00.000Z         0.139869          3.331835e+08
# 13  2024-03-04T06:21:00.000Z        20.265071          6.857405e+08
# 14  2024-03-04T06:21:00.000Z         1.083639          7.707488e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       67.7636                     0.110749
# 1                       47.8015                    -0.098754
# 2                       30.1344                    -0.004250
# 3                       35.6388                    -0.133703
# 4                       40.3326                    -0.109744
# 5                       -1.6076                    -0.785606
# 6                       31.6763                    -0.001804
# 7                       24.5981                     4.603842
# 8                       66.4968                     2.536448
# 9                       -4.7999                    -0.005382
# 10                     -30.8441                     7.621271
# 11                      42.9406                     0.845160
# 12                      22.3017                     0.068266
# 13                      -1.3665                    -0.072869
# 14                       2.1940                    -0.806354
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       2.697468                    23.432304
# 1                       1.591453                    11.849702
# 2                       0.001435                     0.048328
# 3                       1.139717                     7.544943
# 4                      -0.006669                    24.385938
# 5                      -0.772643                    15.745736
# 6                       0.027639                    -0.000182
# 7                       6.769875                    33.071033
# 8                      17.131588                    89.715892
# 9                      -2.042163                    13.888456
# 10                     18.745407                   161.474628
# 11                      7.081559                    25.449918
# 12                     -0.831018                     1.477017
# 13                     -3.384708                     9.224549
# 14                     -0.852057                     8.625011
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      47.438013                     47.381635
# 1                      49.500415                     55.092413
# 2                       0.072663                     -0.020728
# 3                      36.709566                     28.891296
# 4                      29.425855                     28.077030
# 5                      23.157795                      7.610020
# 6                      -0.039227                     -0.023550
# 7                      50.476707                     38.462100
# 8                     105.204638                     97.157859
# 9                      16.961279                     14.313756
# 10                    176.422326                    160.644157
# 11                     42.016993                     27.336733
# 12                     20.434042                     28.906110
# 13                     14.389612                     40.549875
# 14                     36.191797                     25.116191
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      51.819788          1.248896e+12
# 1                      55.144808          4.168001e+11
# 2                       0.050199          9.956539e+10
# 3                      78.643804          6.200144e+10
# 4                     114.057459          5.717024e+10
# 5                       0.796609          3.414839e+10
# 6                      -0.000372          2.894950e+10
# 7                      92.556782          2.766154e+10
# 8                      80.250704          2.328821e+10
# 9                      85.882540          1.596446e+10
# 10                    175.332554          1.482783e+10
# 11                     73.296663          1.261636e+10
# 12                     35.088042          1.230203e+10
# 13                     30.351812          1.189762e+10
# 14                     34.763370          1.072710e+10
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          52.3425                        1.335096e+12
# 1                          17.4743                        4.168001e+11
# 2                           4.1743                        1.028519e+11
# 3                           2.6000                        6.200144e+10
# 4                           2.3961                        7.370407e+10
# 5                           1.4312                        6.246958e+10
# 6                           1.2133                        2.894950e+10
# 7                           1.1600                        3.507896e+10
# 8                           0.9760                        2.328821e+10
# 9                           0.6695                        3.046873e+10
# 10                          0.6218                        1.483398e+10
# 11                          0.5291                        1.391437e+10
# 12                          0.5159                        1.230204e+10
# 13                          0.4989                        2.026507e+10
# 14                          0.4497                        1.083639e+10
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-03-04T06:22:00.000Z          NaN           NaN
# 1           None  2024-03-04T06:22:00.000Z          NaN           NaN
# 2           None  2024-03-04T06:21:00.000Z       1027.0      Ethereum
# 3           None  2024-03-04T06:21:00.000Z          NaN           NaN
# 4           None  2024-03-04T06:22:00.000Z          NaN           NaN
# 5           None  2024-03-04T06:22:00.000Z          NaN           NaN
# 6           None  2024-03-04T06:22:00.000Z       1027.0      Ethereum
# 7           None  2024-03-04T06:21:00.000Z          NaN           NaN
# 8           None  2024-03-04T06:22:00.000Z          NaN           NaN
# 9           None  2024-03-04T06:21:00.000Z          NaN           NaN
# 10          None  2024-03-04T06:21:00.000Z       1027.0      Ethereum
# 11          None  2024-03-04T06:21:00.000Z          NaN           NaN
# 12          None  2024-03-04T06:21:00.000Z          NaN           NaN
# 13          None  2024-03-04T06:21:00.000Z       1027.0      Ethereum
# 14          None  2024-03-04T06:21:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 11             NaN           NaN                                         NaN
# 12             NaN           NaN                                         NaN
# 13             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2024-03-04 11:53:43.433319
# 1  2024-03-04 11:53:43.433319
# 2  2024-03-04 11:53:43.433319
# 3  2024-03-04 11:53:43.433319
# 4  2024-03-04 11:53:43.433319
# 5  2024-03-04 11:53:43.433319
# 6  2024-03-04 11:53:43.433319
# 7  2024-03-04 11:53:43.433319
# 8  2024-03-04 11:53:43.433319
# 9  2024-03-04 11:53:43.433319
# 10 2024-03-04 11:53:43.433319
# 11 2024-03-04 11:53:43.433319
# 12 2024-03-04 11:53:43.433319
# 13 2024-03-04 11:53:43.433319
# 14 2024-03-04 11:53:43.433319

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data
    
    # Use this if you just want to keep it in a dataframe
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = df.append(df2)

# %%
import os 
import pandas as pd  # Import pandas library
from time import sleep

# Initialize an empty DataFrame before the loop
df = pd.DataFrame()

for i in range(333):
    # Assuming api_runner() returns data in DataFrame format
    data = api_runner()
    
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    
    # Append df2 to df
    df = df.append(df2, ignore_index=True)  
    
    print('API Runner completed')
    sleep(60)  # sleep for 1 minute

df.to_csv('output.csv', index=False)


exit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9520\1108686170.py in ?()
#       6 df = pd.DataFrame()
#       7
#       8 for i in range(333):
#       9     # Assuming api_runner() returns data in DataFrame format
# ---> 10     data = api_runner()
#      11
#      12     df2 = pd.json_normalize(data['data'])
#      13     df2['Timestamp'] = pd.to_datetime('now')
#
# ~\AppData\Local\Temp\ipykernel_9520\1431416850.py in ?()
#      28
#      29     # Use this if you just want to keep it in a dataframe
#      30     df2 = pd.json_normalize(data['data'])
#      31     df2['Timestamp'] = pd.to_datetime('now')
# ---> 32     df = df.append(df2)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
#       2 df3
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:985, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     983         in_axis, level, gpr = False, gpr, None
#     984     else:
# --> 985         raise KeyError(gpr)
#     986 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     987     # Add key to exclusions
#     988     exclusions.add(gpr.key)
#
# KeyError: 'name'

# %%
df4 = df3.stack()
df4

# %%
type(df4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 type(df4)
#
# NameError: name 'df4' is not defined

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df5 = df4.to_frame(name='values')
#       2 df5
#
# NameError: name 'df4' is not defined

# %%
df5.count()

# %%
index = pd.Index(range(90))
df6 = df5.set_index(index)
df6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 index = pd.Index(range(90))
# ----> 2 df6 = df5.set_index(index)
#       3 df6
#
# NameError: name 'df5' is not defined

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
